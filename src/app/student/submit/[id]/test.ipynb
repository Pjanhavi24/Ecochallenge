# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\janha\OneDrive\Desktop\CC REPORT\cc_add.csv')

# %%
df
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      2023-12-31  Week-53  Q4          2023
# 1                   96      2023-12-31  Week-53  Q4          2023
# ...

# %%
df.to_csv(r'C:\Users\janha\OneDrive\Desktop\CC REPORT\cc_add.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.to_csv(r'C:\Users\janha\OneDrive\Desktop\CC REPORT\cc_add.csv',index=False)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df.to_csv(r"C:\Users\janha\OneDrive\Desktop\CC REPORT\cc_add_new.csv", index=False)
